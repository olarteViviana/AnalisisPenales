# %% [markdown]
# ![](img\Architecture.jpg)

# %%
#Librerías

# %pip install pandas requests beautifulsoup4 langchain-mongodb pymongo python-dotenv langchain-openai langchain-nomic

import pandas as pd
from langchain_mongodb import MongoDBAtlasVectorSearch
from langchain_community.document_loaders.mongodb import MongodbLoader
import nest_asyncio
from pymongo.mongo_client import MongoClient
import os
from dotenv import load_dotenv
from langchain_nomic import NomicEmbeddings
import pymongo
import json
# Out:
# Requirement already satisfied: pandas in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: requests in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (4.12.3)
# Requirement already satisfied: langchain-mongodb in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (0.2.0)
# Requirement already satisfied: pymongo in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (4.9.2)
# Requirement already satisfied: python-dotenv in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (1.0.1)
# Requirement already satisfied: langchain-openai in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (0.2.5)
# Requirement already satisfied: langchain-nomic in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (0.1.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain-mongodb) (0.3.15)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from pymongo) (2.7.0)
# Requirement already satisfied: openai<2.0.0,>=1.52.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain-openai) (1.52.2)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain-openai) (0.8.0)
# Requirement already satisfied: nomic<4.0.0,>=3.1.2 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain-nomic) (3.2.0)
# Requirement already satisfied: pillow<11.0.0,>=10.3.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain-nomic) (10.4.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-mongodb) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-mongodb) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-mongodb) (0.1.138)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-mongodb) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-mongodb) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-mongodb) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-mongodb) (4.12.2)
# Requirement already satisfied: click in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from nomic<4.0.0,>=3.1.2->langchain-nomic) (8.1.7)
# Requirement already satisfied: jsonlines in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from nomic<4.0.0,>=3.1.2->langchain-nomic) (4.0.0)
# Requirement already satisfied: loguru in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from nomic<4.0.0,>=3.1.2->langchain-nomic) (0.7.2)
# Requirement already satisfied: rich in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from nomic<4.0.0,>=3.1.2->langchain-nomic) (13.9.3)
# Requirement already satisfied: tqdm in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from nomic<4.0.0,>=3.1.2->langchain-nomic) (4.66.5)
# Requirement already satisfied: pyarrow in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from nomic<4.0.0,>=3.1.2->langchain-nomic) (18.0.0)
# Requirement already satisfied: pyjwt in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from nomic<4.0.0,>=3.1.2->langchain-nomic) (2.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (0.6.1)
# Requirement already satisfied: sniffio in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (1.3.1)
# Requirement already satisfied: six>=1.5 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.9.11)
# Requirement already satisfied: httpcore==1.* in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.52.0->langchain-openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.52.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain-mongodb) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-mongodb) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-mongodb) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.3->langchain-mongodb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.3->langchain-mongodb) (2.23.4)
# Requirement already satisfied: colorama in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from tqdm->nomic<4.0.0,>=3.1.2->langchain-nomic) (0.4.6)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from jsonlines->nomic<4.0.0,>=3.1.2->langchain-nomic) (24.2.0)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from loguru->nomic<4.0.0,>=3.1.2->langchain-nomic) (1.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from rich->nomic<4.0.0,>=3.1.2->langchain-nomic) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from rich->nomic<4.0.0,>=3.1.2->langchain-nomic) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->nomic<4.0.0,>=3.1.2->langchain-nomic) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
load_dotenv()
os.environ["USER_AGENT"] = "MyApp/1.0"
os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')
os.environ["LANGCHAIN_API_KEY"] = os.getenv('LANGCHAIN_API_KEY')

# %%
termino_de_busqueda = input('Ingrese el término de búsqueda: ')
termino_de_busqueda = termino_de_busqueda.replace(' ', '+')

# %%
# Definir el encabezado con el User-Agent
from bs4 import BeautifulSoup
import requests

#Construcción url
URL = 'https://www.corteconstitucional.gov.co/relatoria/buscador_new/?searchOption=texto&fini=1992-01-01&ffin=2024-10-29&buscar_por='+ termino_de_busqueda +'&accion=search&verform=si&slop=1&volver_a=relatoria&qu=625&maxprov=100&OrderbyOption=des__score'

# Realizar la solicitud GET a la página
response = requests.get(URL)

# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    # Parsear el contenido HTML con BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')

    # Encontrar todas las etiquetas 'a' con atributo 'href'
    enlaces = [a['href'] for a in soup.find_all('a', href=True)]
else:
    print(f"Error al acceder a la página: {response.status_code}")

# crear una lista con los enlaces obtenidos anteriormente

lista_enlaces = []

# Encontrar todas las etiquetas 'a' con atributo 'href'
for a in soup.find_all('a', href=True):
  lista_enlaces.append(a['href'])


# filtrar lista_enlaces y coger solo los enlaces contengan la palabra relatoria

enlaces_relatoria = [enlace for enlace in lista_enlaces if 'relatoria' in enlace]
enlaces_relatoria = [enlace for enlace in enlaces_relatoria if len(enlace) > 49]

# Imprimir la lista de enlaces filtrados
enlaces_relatoria
# Out:
# ['https://www.corteconstitucional.gov.co/relatoria/2024/T-394-24.htm']

# %%
# diccionario_relatorias
diccionario_relatorias = {}

for enlace in enlaces_relatoria:
    try:
        nota = requests.get(enlace)
        nota.raise_for_status()  # Verifica si hubo algún problema con la respuesta HTTP
        s_nota = BeautifulSoup(nota.text, 'html.parser')
        texto = (s_nota.find('div', attrs={'class': 'WordSection1'}).text).strip()
        diccionario_relatorias[enlace] = texto
    except requests.exceptions.RequestException as e:
        print(f"Error al solicitar el enlace {enlace}: {e}")
    except AttributeError:
        try:
            # Si no encuentra 'WordSection1', intenta con 'Section1'
            texto = (s_nota.find('div', attrs={'class': 'Section1'}).text).strip()
            diccionario_relatorias[enlace] = texto
        except AttributeError as e:
            print(f"Error procesando el contenido del enlace {enlace}: {e}")

diccionario_relatorias
# Out:
# {'https://www.corteconstitucional.gov.co/relatoria/2024/T-394-24.htm': 'REPÚBLICA DE COLOMBIA\n\xa0\n\n\xa0\nCORTE CONSTITUCIONAL\nSala Cuarta de Revisión\n\xa0\nSENTENCIA T-394 DE 2024\n\xa0\n\xa0\nReferencia:\nexpediente T-9.359.163\n\xa0\nRevisión de las decisiones judiciales relacionadas con\r\nla solicitud de tutela presentada por Mónica\r\nMaría Restrepo Palacios, representante legal de la sociedad El Colombiano\r\nS.A.S., contra Daniel Quintero Calle\n\xa0\nMagistrado sustanciador:\nANTONIO JOSÉ LIZARAZO OCAMPO\n\xa0\n\xa0\n\n\n\n\nSíntesis de la decisión. La Sala Cuarta de Revisión declaró improcedente la solicitud de\r\n  tutela presentada por la representante legal de El Colombiano contra el\r\n  entonces alcalde de Medellín, Daniel Quintero Calle, porque no cumplió el\r\n  requisito de subsidiariedad. Al respecto, advirtió que, a pesar de que la\r\n  accionante no pretendía que el alcalde rectificara o eliminara los mensajes\r\n  publicados en su cuenta de Twitter relacionados con el medio de comunicación,\r\n  lo cierto es que, en efecto, cuestionaba y juzgaba su contenido. \n\xa0\nLa Sala concluyó que la accionante no cumplió los requisitos de\r\n  procedencia en materia de tutela para amparar la libertad de expresión cuando\r\n  la amenaza o el daño a dicha libertad se realiza mediante el uso de redes\r\n  sociales. Así las cosas, señaló que, en el presente caso, la accionante debió\r\n  solicitar la rectificación de la información al exalcalde, pues esta constituye prerrequisito\r\n  para la procedencia de la tutela con el objeto de obtener la protección de tal\r\n  libertad, independientemente de que los canales de divulgación de\r\n  información que se utilicen sean distintos de los tradicionales (prensa,\r\n  radio, televisión, etc.), como es el caso de los portales de internet y las\r\n  redes sociales.\n\n\n\n\n\xa0\n\xa0\nBogotá D. C., diecinueve (19) de septiembre de dos mil veinticuatro (2024)\n\xa0\nLa Sala\r\nCuarta de Revisión de la Corte Constitucional, en ejercicio de sus competencias\r\nconstitucionales y legales, decide sobre los fallos proferidos, en primera\r\ninstancia, por el Juzgado 29 Civil Municipal de Medellín, y, en\r\nsegunda instancia, por el Juzgado Quinto Civil del Circuito de Oralidad de Medellín, dentro del proceso de la referencia[1], previas las siguientes consideraciones. \n\xa0\n\xa0\nI. ANTECEDENTES\n\xa0\nA. Solicitud\n\xa0\n1.\xa0\xa0\r\nLa solicitud fue presentada el 17 de\r\nenero de 2023 por Mónica María Restrepo Palacios, en\r\ncalidad de representante legal del periódico El Colombiano S.A.S., contra Daniel\r\nQuintero Calle, quien para la época ocupaba el cargo de alcalde de Medellín, por\r\nconsiderar vulnerados los derechos fundamentales del medio de comunicación a la libertad de expresión, a la libertad de prensa, al\r\nbuen nombre y a la no discriminación. Lo anterior, debido a las publicaciones\r\nque el señor Quintero realizó en sus redes sociales cuestionando la imparcialidad\r\ndel diario.\n\xa0\nB. Hechos relevantes\n\xa0\n2.\xa0\xa0\r\nLa solicitante afirmó que Daniel\r\nQuintero Calle ha propiciado escenarios de acoso y \x93violencia\r\nen línea\x94[2],\r\nen contra del periódico El Colombiano. En concreto, trajo a colación quince situaciones\r\npuntuales que, a su juicio, darían cuenta del interés del\r\nservidor público por desprestigiar y estigmatizar la labor del medio de\r\ncomunicación escrito y suscitar escenarios de violencia en contra del diario y\r\nde sus trabajadores.\n\xa0\n3.\xa0\xa0\r\nAgregó que los mensajes del servidor público tienen\r\nun impacto relevante en la opinión pública, pues se trata de un líder político\r\ncuya voz tiene una importante capacidad de incidencia. Para la solicitante, no\r\ncabe duda de que la conducta del alcalde de la ciudad Medellín repercute en la\r\nseguridad del periódico y de sus periodistas, pues, según su criterio, los\r\nmensajes \x93incitan al odio contra el medio y las personas que trabajan en el\r\nmismo\x ...

# %%
# convertir el diccionario en un df de pandas

df = pd.DataFrame(list(diccionario_relatorias.items()), columns=['Enlace', 'Texto'])

df['Sentencia'] = df['Enlace'].str.split('/relatoria/').str[-1].str.split('.htm').str[0]

# Reorganizar el DataFrame
df = df[['Sentencia', 'Texto']]  # Selecciona las columnas en el orden deseado

# %%
# exportar el df en formato JSON Lines

nombre_json = ('sentencias_' + termino_de_busqueda).replace('+', '_') + '.jsonl'
# Assuming df is your DataFrame
df.to_json(nombre_json, orient='records', lines=True)

# %%
client = pymongo.MongoClient(os.environ['MONGODB_URI'])
collections = client.get_database(os.environ['MONGODB_DB']).get_collection(os.environ['MONGODB_COLLECTION'])

# %%
collections.delete_many({})
# Out:
# DeleteResult({'n': 0, 'electionId': ObjectId('7fffffff000000000000015d'), 'opTime': {'ts': Timestamp(1732117331, 7), 't': 349}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1732117331, 7), 'signature': {'hash': b'\x07\xa3\xafE\x17e>_\xa8@{\x19\xcc\x11\x9f\xfc\x04y\x83\x8e', 'keyId': 7400451993602359319}}, 'operationTime': Timestamp(1732117331, 7)}, acknowledged=True)

# %%
# Leer el archivo JSON Lines y cargar los documentos
with open(nombre_json, 'r') as f:
    docs_to_insert = [json.loads(line) for line in f]

# %%
# %pip install langchain

from langchain.text_splitter import CharacterTextSplitter
from langchain.docstore.document import Document

docs_to_insert = [
    Document(page_content=doc['Texto'], metadata={'sentencia': doc['Sentencia']})
    for doc in docs_to_insert
]

def custom_split(text, max_size=1000):
    chunks = []
    while len(text) > max_size:
        chunk = text[:max_size]
        chunks.append(chunk)
        text = text[max_size:]
    if text:
        chunks.append(text)
    return chunks

docs_splits = []
for doc in docs_to_insert:
    chunks = custom_split(doc.page_content)
    for chunk in chunks:
        docs_splits.append(Document(page_content=chunk, metadata=doc.metadata))
docs_splits_dict = [doc.dict() for doc in docs_splits]

collections.insert_many(docs_splits_dict)
# Out:
# Requirement already satisfied: langchain in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (0.3.6)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain) (3.10.10)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.14 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.3.15)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.3.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.1.138)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.17.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.4.0,>=0.3.14->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.4.0,>=0.3.14->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.4.0,>=0.3.14->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: anyio in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.14->langchain) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Note: you may need to restart the kernel to use updated packages.
# InsertManyResult([ObjectId('673e035e0dca7c202b9033dc'), ObjectId('673e035e0dca7c202b9033dd'), ObjectId('673e035e0dca7c202b9033de'), ObjectId('673e035e0dca7c202b9033df'), ObjectId('673e035e0dca7c202b9033e0'), ObjectId('673e035e0dca7c202b9033e1'), ObjectId('673e035e0dca7c202b9033e2'), ObjectId('673e035e0dca7c202b9033e3'), ObjectId('673e035e0dca7c202b9033e4'), ObjectId('673e035e0dca7c202b9033e5'), ObjectId('673e035e0dca7c202b9033e6'), ObjectId('673e035e0dca7c202b9033e7'), ObjectId('673e035e0dca7c202b9033e8'), ObjectId('673e035e0dca7c202b9033e9'), ObjectId('673e035e0dca7c202b9033ea'), ObjectId('673e035e0dca7c202b9033eb'), ObjectId('673e035e0dca7c202b9033ec'), ObjectId('673e035e0dca7c202b9033ed'), ObjectId('673e035e0dca7c202b9033ee'), ObjectId('673e035e0dca7c202b9033ef'), ObjectId('673e035e0dca7c202b9033f0'), ObjectId('673e035e0dca7c202b9033f1'), ObjectId('673e035e0dca7c202b9033f2'), ObjectId('673e035e0dca7c202b9033f3'), ObjectId('673e035e0dca7c202b9033f4'), ObjectId('673e035e0dca7c202b9033f5'), ObjectId('673e035e0dca7c202b9033f6'), ObjectId('673e035e0dca7c202b9033f7'), ObjectId('673e035e0dca7c202b9033f8'), ObjectId('673e035e0dca7c202b9033f9'), ObjectId('673e035e0dca7c202b9033fa'), ObjectId('673e035e0dca7c202b9033fb'), ObjectId('673e035e0dca7c202b9033fc'), ObjectId('673e035e0dca7c202b9033fd'), ObjectId('673e035e0dca7c202b9033fe'), ObjectId('673e035e0dca7c202b9033ff'), ObjectId('673e035e0dca7c202b903400'), ObjectId('673e035e0dca7c202b903401'), ObjectId('673e035e0dca7c202b903402'), ObjectId('673e035e0dca7c202b903403'), ObjectId('673e035e0dca7c202b903404'), ObjectId('673e035e0dca7c202b903405'), ObjectId('673e035e0dca7c202b903406'), ObjectId('673e035e0dca7c202b903407'), ObjectId('673e035e0dca7c202b903408'), ObjectId('673e035e0dca7c202b903409'), ObjectId('673e035e0dca7c202b90340a'), ObjectId('673e035e0dca7c202b90340b'), ObjectId('673e035e0dca7c202b90340c'), ObjectId('673e035e0dca7c202b90340d'), ObjectId('673e035e0dca7c202b90340e'), ObjectId('673e035e0dca7c202b90340f'), ObjectId('673e035e0dca7c202b903410'), ObjectId('673e035e0dca7c202b903411'), ObjectId('673e035e0dca7c202b903412'), ObjectId('673e035e0dca7c202b903413'), ObjectId('673e035e0dca7c202b903414'), ObjectId('673e035e0dca7c202b903415'), ObjectId('673e035e0dca7c202b903416'), ObjectId('673e035e0dca7c202b903417'), ObjectId('673e035e0dca7c202b903418'), ObjectId('673e035e0dca7c202b903419'), ObjectId('673e035e0dca7c202b90341a'), ObjectId('673e035e0dca7c202b90341b'), ObjectId('673e035e0dca7c202b90341c'), ObjectId('673e035e0dca7c202b90341d'), ObjectId('673e035e0dca7c202b90341e'), ObjectId('673e035e0dca7c202b90341f'), ObjectId('673e035e0dca7c202b903420'), ObjectId('673e035e0dca7c202b903421'), ObjectId('673e035e0dca7c202b903422'), ObjectId('673e035e0dca7c202b903423'), ObjectId('673e035e0dca7c202b903424'), ObjectId('673e035e0dca7c202b903425'), ObjectId('673e035e0dca7c202b903426'), ObjectId('673e035e0dca7c202b903427'), ObjectId('673e035e0dca7c202b903428'), ObjectId('673e035e0dca7c202b903429'), ObjectId('673e035e0dca7c202b90342a'), ObjectId('673e035e0dca7c202b90342b'), ObjectId('673e035e0dca7c202b90342c'), ObjectId('673e035e0dca7c202b90342d'), ObjectId('673e035e0dca7c202b90342e'), ObjectId('673e035e0dca7c202b90342f'), ObjectId('673e035e0dca7c202b903430'), ObjectId('673e035e0dca7c202b903431'), ObjectId('673e035e0dca7c202b903432'), ObjectId('673e035e0dca7c202b903433'), ObjectId('673e035e0dca7c202b903434'), ObjectId('673e035e0dca7c202b903435'), ObjectId('673e035e0dca7c202b903436'), ObjectId('673e035e0dca7c202b903437'), ObjectId('673e035e0dca7c202b903438'), ObjectId('673e035e0dca7c202b903439'), ObjectId('673e035e0dca7c202b90343a'), ObjectId('673e035e0dca7c202b90343b'), ObjectId('673e035e0dca7c202b90343c'), ObjectId('673e035e0dca7c202b90343d'), ObjectId('673e035e0dca7c202b90343e'), ObjectId('673e035e0dca7c202b90343f'), ObjectId('673e035e0dca7c202b903440'), ObjectId('673e035e0dca7c202b903441'), ObjectId('673e035e0dca7c202b903442'), ObjectId('673e035e0dca7c202b903443'), ObjectId('673e035e0dca7c202b90 ...

# %%
# %pip install motor
nest_asyncio.apply()
load_dotenv()
loader = MongodbLoader(
    connection_string=os.environ['MONGODB_URI'],
    db_name=os.environ['MONGODB_DB'],
    collection_name=os.environ['MONGODB_COLLECTION'],
    filter_criteria={},
    field_names=["metadata", "page_content"],
)
docs = loader.load()
# Out:
# Requirement already satisfied: motor in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (3.6.0)
# Requirement already satisfied: pymongo<4.10,>=4.9 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from motor) (4.9.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\olart\appdata\local\programs\python\python312\lib\site-packages (from pymongo<4.10,>=4.9->motor) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")
# Out:
# C:\Users\olart\AppData\Local\Temp\ipykernel_3200\1010149463.py:3: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")

# %%
vectorStore = MongoDBAtlasVectorSearch.from_documents( 
    documents= docs,
    embedding= embeddings, 
    collection= collections,
    index_name=os.environ['MONGODB_VECTOR_INDEX']
)

# %%
retriever = vectorStore.as_retriever(search_kwargs={"similarity_threshold": 0.1})

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_ollama import ChatOllama

template = """Quiero un análisis jurídico profesional sobre los derechos fundamentales amenazados o dañados que se debaten en la Corte Constitucional de Colombia. Es importante conocer los hechos de acuerdo a las circunstancias de modo, el tiempo con las fechas y hora, el lugar
donde ocurrieron y las personas naturales o jurídicas que tienen conflicto entre ellas. También es importante conocer cuál fue el daño o peligro que afecta los derechos fundamentales dentro de las consideraciones tenidas en cuenta por la Corte Constitucional. Finalmente, requiero saber lo que resuelve la Corte Constitucional. Con base en las anteriores instrucciones, proporciona un resumen de:
{context}

Question: {question}
"""
prompt = ChatPromptTemplate.from_template(template)

model = ChatOpenAI(temperature=0, model="gpt-4o")

# Local LLM
ollama_llm = "phi3.5"
model_local = ChatOllama(model=ollama_llm)

chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | model
    | StrOutputParser()
)

query = """ De la sentencia T-394-24, responde estos 5 puntos:
	1.	Los hechos de la sentencia.
	2.	Los derechos fundamentales en discusión dentro de la sentencia.
	3.	Las consideraciones más relevantes de la Corte Constitucional en su análisis y decisión.
	4.	La conclusión o sentencia emitida por la Corte.
	5.	Cuál es el razonamiento jurídico que utiliza la Corte Constitucional para conceder o negar derechos fundamentales?"""
results = chain.invoke(query)
print(results)
# Out:
# Para proporcionar un análisis detallado de la sentencia T-394-24 de la Corte Constitucional de Colombia, abordaré los cinco puntos solicitados:
#
# 1. **Los hechos de la sentencia:**
#    La sentencia T-394-24 se centra en un conflicto entre el medio de comunicación "El Colombiano" y el señor Daniel Quintero Calle. El medio de comunicación presentó una acción de tutela solicitando la protección de sus derechos fundamentales, alegando que estos habían sido afectados por publicaciones realizadas por Quintero Calle. La acción de tutela fue presentada debido a que "El Colombiano" consideró que no existía otro medio idóneo y eficaz para proteger sus derechos.
#
# 2. **Los derechos fundamentales en discusión dentro de la sentencia:**
#    Los derechos fundamentales en discusión incluyen la libertad de expresión, la libertad de prensa, el buen nombre y la no discriminación. "El Colombiano" buscaba el amparo de estos derechos, argumentando que las publicaciones de Quintero Calle afectaban su buen nombre y constituían actos de discriminación.
#
# 3. **Las consideraciones más relevantes de la Corte Constitucional en su análisis y decisión:**
#    La Corte Constitucional analizó la procedencia de la acción de tutela, especialmente en relación con el requisito de subsidiariedad. La Corte consideró que, aunque existen acciones penales y civiles para abordar este tipo de conflictos, en este caso específico, la acción de tutela era procedente debido a la relevancia constitucional del asunto y la falta de otros medios idóneos para proteger los derechos fundamentales del medio de comunicación.
#
# 4. **La conclusión o sentencia emitida por la Corte:**
#    La Corte Constitucional decidió que la acción de tutela era procedente y debía ampararse los derechos fundamentales del medio de comunicación "El Colombiano". La Corte concluyó que los derechos al buen nombre y a la no discriminación habían sido afectados de manera reiterada y sistemática por las acciones de Quintero Calle.
#
# 5. **Cuál es el razonamiento jurídico que utiliza la Corte Constitucional para conceder o negar derechos fundamentales:**
#    La Corte utilizó el razonamiento de que la acción de tutela es un mecanismo definitivo cuando no existen otros medios idóneos y eficaces para proteger los derechos fundamentales. En este caso, la Corte determinó que la acción de tutela cumplía con el requisito de relevancia constitucional y que no se había acreditado el requisito de subsidiariedad respecto a los derechos al buen nombre y a la no discriminación. Por lo tanto, la Corte decidió conceder la tutela para proteger estos derechos fundamentales del medio de comunicación.
#
# Este análisis proporciona un resumen de los aspectos clave de la sentencia T-394-24, destacando los hechos, los derechos en discusión, las consideraciones de la Corte, la conclusión y el razonamiento jurídico utilizado.
